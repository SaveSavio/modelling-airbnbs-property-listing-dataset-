# %% [markdown]
# # Data Cleaning
# Contains steps and logic behind the data cleaning.

# %% [markdown]
# Start by defining a function called remove_rows_with_missing_ratings which removes the rows with missing values in these columns. It should take in the dataset as a pandas dataframe and return the same type.

# %%
import pandas as pd
df = pd.read_csv("./airbnb-property-listings/tabular_data/listing.csv")

# %%
df.head()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                                     Hanging cabin
#
#                                          Description  \
# 0  ['About this space', "Escape to one of these t...
# 1  ['About this space', "Come and spend a romanti...
# 2  ['About this space', 'Rustic cabin between the...
# 3  ['About this space', 'The Tree top cabin is si...
# 4  ['About this space', 'Feel refreshed at this u...
#
#                                            Amenities  \
# 0  ['What this place offers', 'Bathroom', 'Shampo...
# 1  ['What this place offers', 'Bedroom and laundr...
# 2  ['What this place offers', 'Scenic views', 'Ga...
# 3  ['What this place offers', 'Bathroom', 'Hot wa...
# 4  ['What this place offers', 'Heating and coolin...
#
#                                    Location guests  beds  bathrooms  \
# 0          Llandrindod Wells United Kingdom      2   1.0        1.0
# 1               Guyonvelle Grand Est France      3   3.0        0.0
# 2                  Duclair Normandie France      4   2.0        1.5
# 3             Barmouth Wales United Kingdom      2   NaN        1.0
# 4  Wargnies-le-Petit Hauts-de-France France      2   1.0        NaN
#
#    Price_Night  Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 0          105                 4.6              4.7                   4.3
# 1           92                 4.3              4.7                   4.6
# 2           52                 4.2              4.6                   4.8
# 3          132                 4.8              4.9                   4.9
# 4          111                 NaN              NaN                   NaN
#
#    Location_rating  Check-in_rating  Value_rating  amenities_count  \
# 0              5.0              4.3           4.3             13.0
# 1              4.9              4.7           4.5              8.0
# 2              4.8              4.8           4.7             51.0
# 3              4.9              5.0           4.6             23.0
# 4              NaN              NaN           NaN              5.0
#
#                                                  url bedrooms  Unnamed: 19
# 0  https://www.airbnb.co.uk/rooms/26620994?adults...      NaN          NaN
# 1  https://www.airbnb.co.uk/rooms/27055498?adults...        1          NaN
# 2  https://www.airbnb.co.uk/rooms/51427108?adults...        1          NaN
# 3  https://www.airbnb.co.uk/rooms/49543851?adults...      NaN          NaN
# 4  https://www.airbnb.co.uk/rooms/50166553?adults...        1          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    988 non-null    object
#  1   Category              988 non-null    object
#  2   Title                 988 non-null    object
#  3   Description           900 non-null    object
#  4   Amenities             988 non-null    object
#  5   Location              988 non-null    object
#  6   guests                969 non-null    object
#  7   beds                  945 non-null    float64
#  8   bathrooms             888 non-null    float64
#  9   Price_Night           988 non-null    int64
#  10  Cleanliness_rating    890 non-null    float64
#  11  Accuracy_rating       890 non-null    float64
#  12  Communication_rating  890 non-null    float64
#  13  Location_rating       890 non-null    float64
#  14  Check-in_rating       890 non-null    float64
#  15  Value_rating          890 non-null    float64
#  16  amenities_count       988 non-null    float64
#  17  url                   988 non-null    object
#  18  bedrooms              906 non-null    object
#  19  Unnamed: 19           1 non-null      float64
# dtypes: float64(10), int64(1), object(9)
# memory usage: 154.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description              88
# Amenities                 0
# Location                  0
# guests                   19
# beds                     43
# bathrooms               100
# Price_Night               0
# Cleanliness_rating       98
# Accuracy_rating          98
# Communication_rating     98
# Location_rating          98
# Check-in_rating          98
# Value_rating             98
# amenities_count           0
# url                       0
# bedrooms                 82
# Unnamed: 19             987
# dtype: int64

# %%
pd.set_option('display.max_rows', 20)
df[["Cleanliness_rating", "Accuracy_rating", "Communication_rating", "Location_rating", "Check-in_rating", "Value_rating"]][df['Cleanliness_rating'].isna()]
# Out:
#      Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 4                   NaN              NaN                   NaN
# 9                   NaN              NaN                   NaN
# 15                  NaN              NaN                   NaN
# 16                  NaN              NaN                   NaN
# 17                  NaN              NaN                   NaN
# ..                  ...              ...                   ...
# 967                 NaN              NaN                   NaN
# 969                 NaN              NaN                   NaN
# 971                 NaN              NaN                   NaN
# 973                 NaN              NaN                   NaN
# 986                 NaN              NaN                   NaN
#
#      Location_rating  Check-in_rating  Value_rating
# 4                NaN              NaN           NaN
# 9                NaN              NaN           NaN
# 15               NaN              NaN           NaN
# 16               NaN              NaN           NaN
# 17               NaN              NaN           NaN
# ..               ...              ...           ...
# 967              NaN              NaN           NaN
# 969              NaN              NaN           NaN
# 971              NaN              NaN           NaN
# 973              NaN              NaN           NaN
# 986              NaN              NaN           NaN
#
# [98 rows x 6 columns]

# %% [markdown]
# The cleaning is pretty simple because all the rows miss the rating at the same time.

# %%
df = df[df['Cleanliness_rating'].notna()]

# %%
df.isna().sum()
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description              60
# Amenities                 0
# Location                  0
# guests                   18
# beds                     34
# bathrooms                79
# Price_Night               0
# Cleanliness_rating        0
# Accuracy_rating           0
# Communication_rating      0
# Location_rating           0
# Check-in_rating           0
# Value_rating              0
# amenities_count           0
# url                       0
# bedrooms                 76
# Unnamed: 19             889
# dtype: int64

# %%
df.dtypes
# Out:
# ID                       object
# Category                 object
# Title                    object
# Description              object
# Amenities                object
# Location                 object
# guests                   object
# beds                    float64
# bathrooms               float64
# Price_Night               int64
# Cleanliness_rating      float64
# Accuracy_rating         float64
# Communication_rating    float64
# Location_rating         float64
# Check-in_rating         float64
# Value_rating            float64
# amenities_count         float64
# url                      object
# bedrooms                 object
# Unnamed: 19             float64
# dtype: object

# %% [markdown]
# The "Description" column contains lists of strings. You'll need to define a function called combine_description_strings which combines the list items into the same string.
#
# Unfortunately, pandas doesn't recognise the values as lists, but as strings whose contents are valid Python lists.
#
# You should look up how to do this (don't implement a from-scratch solution to parse the string into a list). The lists contain many empty quotes which should be removed. If you don't remove them before joining the list elements with a whitespace, they might cause the result to contain multiple whitespaces in places. The function should take in the dataset as a pandas dataframe and return the same type. It should remove any records with a missing description, and also remove the "About this space" prefix which every description starts with.
#
# The "guests", "beds", "bathrooms", and "bedrooms" columns have empty values for some rows. Don't remove them, instead, define a function called set_default_feature_values, and replace these entries with the number 1. It should take in the dataset as a pandas dataframe and return the same type.

# %%
# have to remove those lines without description. Modify this code.
df = df[df['Description'].isnull() == False]

# %%
sample = df['Description'].sample()
print(sample)
print(sample.str.replace("'About this space', ", ''))
print(sample.str.replace(" 'The space', 'The space\n", ''))
print(sample.str.replace(r'\n\n', ' '))
print(sample.str.replace(r'\n', ' '))
print(sample.str.replace("''", ""))
print(sample.apply(eval))
#print(sample)
# Out:
# 738    ['About this space', 'Free pickup in new TESLA...
# Name: Description, dtype: object
# 738    ['Free pickup in new TESLA! Starting from late...
# Name: Description, dtype: object
# 738    ['About this space', 'Free pickup in new TESLA...
# Name: Description, dtype: object
# 738    ['About this space', 'Free pickup in new TESLA...
# Name: Description, dtype: object
# 738    ['About this space', 'Free pickup in new TESLA...
# Name: Description, dtype: object
# 738    ['About this space', 'Free pickup in new TESLA...
# Name: Description, dtype: object
# 738    [About this space, Free pickup in new TESLA! S...
# Name: Description, dtype: object

# %%
df = pd.read_csv("./airbnb-property-listings/tabular_data/listing.csv")

def combine_description_strings(df):
    df['Description'] = df['Description'].str.replace("'About this space', ", '')
    df['Description'] = df['Description'].str.replace(" 'The space', 'The space\n", '')
    df['Description'] = df['Description'].str.replace(r'\n\n', ' ')
    df['Description'] = df['Description'].str.replace(r'\n', ' ')
    df['Description'] = df['Description'].replace("''", "")
    return df

sample = combine_description_strings(df.sample())
sample
# Out:
#                                        ID    Category                 Title  \
# 142  c4e32eed-c3cd-4d4a-831b-a8e7e720b645  Treehouses  Tradewinds Treehouse
#
#                                            Description  \
# 142  ['The Trade Winds Treehouse is simply our most...
#
#                                              Amenities  \
# 142  ['What this place offers', 'Bathroom', 'Hot wa...
#
#                            Location guests  beds  bathrooms  Price_Night  \
# 142  Stanton Kentucky United States      8   5.0        1.0          510
#
#      Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 142                 4.7              4.8                   4.9
#
#      Location_rating  Check-in_rating  Value_rating  amenities_count  \
# 142              4.9              4.9           4.5             14.0
#
#                                                    url bedrooms  Unnamed: 19
# 142  https://www.airbnb.co.uk/rooms/25002039?adults...        3          NaN

# %%
# # Your original text
# original_text = '["Escape to one of these two fabulous Tree Tents... very patchy mobile signal and limited internet connectivity.\']'

# # Clean and transform the text
# cleaned_text = eval(original_text)  # This will convert the text into a list
# cleaned_text = '\n'.join(cleaned_text)  # Join the list elements into a single string

# # Now, 'cleaned_text' contains the transformed text as a string
# print(cleaned_text)

# %%
import pandas as pd
df = pd.read_csv("./airbnb-property-listings/tabular_data/clean_tabular_data.csv")
df
# Out:
#      Unnamed: 0                                    ID    Category  \
# 0             0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1             1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2             2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3             3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4             5  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..          ...                                   ...         ...
# 884         982  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 885         983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 886         984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 887         985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 888         987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# 4                          Treehouse near Paris Disney
# ..                                                 ...
# 884                            Lancing Beach Apartment
# 885                                          Apartment
# 886               Sea front flat with a stunning view!
# 887  MP713 - Camber Sands Holiday Park - Sleeps 6 +...
# 888                      Sea Scene's ,  Hayling Island
#
#                                            Description  \
# 0    ["Escape to one of these two fabulous Tree Ten...
# 1    ["Come and spend a romantic stay with a couple...
# 2    ['Rustic cabin between the pines, 3 meters hig...
# 3    ['The Tree top cabin is situated in our peacef...
# 4    ['Charming cabin nestled in the leaves, real u...
# ..                                                 ...
# 884  ['An apartment directly on the beach at Lancin...
# 885  ['Light roomy space with outside garden 5 minu...
# 886  ['This specious two bedroom flat on the sea fr...
# 887  ['With all the modern amenities, our contempor...
# 888  ['Sea Scenes is a homely two bedroom groundflo...
#
#                                              Amenities  \
# 0    ['What this place offers', 'Bathroom', 'Shampo...
# 1    ['What this place offers', 'Bedroom and laundr...
# 2    ['What this place offers', 'Scenic views', 'Ga...
# 3    ['What this place offers', 'Bathroom', 'Hot wa...
# 4    ['What this place offers', 'Bathroom', 'Hair d...
# ..                                                 ...
# 884  ['What this place offers', 'Bathroom', 'Hair d...
# 885  ['What this place offers', 'Bathroom', 'Hair d...
# 886  ['What this place offers', 'Scenic views', 'Be...
# 887  ['What this place offers', 'Bathroom', 'Hot wa...
# 888  ['What this place offers', 'Bathroom', 'Hair d...
#
#                                         Location  guests  beds  bathrooms  \
# 0               Llandrindod Wells United Kingdom       2   1.0        1.0
# 1                    Guyonvelle Grand Est France       3   3.0        0.0
# 2                       Duclair Normandie France       4   2.0        1.5
# 3                  Barmouth Wales United Kingdom       2   1.0        1.0
# 4    Le Plessis-Feu-Aussoux Île-de-France France       4   3.0        1.0
# ..                                           ...     ...   ...        ...
# 884                       Lancing United Kingdom       4   2.0        1.5
# 885     Brighton and Hove England United Kingdom       2   1.0        1.0
# 886           East Sussex England United Kingdom       4   2.0        1.5
# 887                Camber England United Kingdom       6   3.0        2.0
# 888      Hayling Island Hampshire United Kingdom       4   2.0        1.0
#
#      ...  Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 0    ...                 4.6              4.7                   4.3
# 1    ...                 4.3              4.7                   4.6
# 2    ...                 4.2              4.6                   4.8
# 3    ...                 4.8              4.9                   4.9
# 4    ...                 5.0              4.9                   5.0
# ..   ...                 ...              ...                   ...
# 884  ...                 4.9              5.0                   5.0
# 885  ...                 4.8              5.0                   4.9
# 886  ...                 4.8              5.0                   5.0
# 887  ...                 4.7              4.8                   5.0
# 888  ...                 4.9              4.9                   4.9
#
#      Location_rating  Check-in_rating  Value_rating  amenities_count  \
# 0                5.0              4.3           4.3             13.0
# 1                4.9              4.7           4.5              8.0
# 2                4.8              4.8           4.7             51.0
# 3                4.9              5.0           4.6             23.0
# 4                4.7              5.0           4.7             32.0
# ..               ...              ...           ...              ...
# 884              5.0              4.9           4.8             33.0
# 885              4.9              5.0           4.9             54.0
# 886              5.0              5.0           4.8             38.0
# 887              5.0              5.0           4.7             24.0
# 888              4.9              4.9           4.3             29.0
#
#                                                    url bedrooms  Unnamed: 19
# 0    https://www.airbnb.co.uk/rooms/26620994?adults...        1          NaN
# 1    https://www.airbnb.co.uk/rooms/27055498?adults...        1          NaN
# 2    https://www.airbnb.co.uk/rooms/51427108?adults...        1          NaN
# 3    https://www.airbnb.co.uk/rooms/49543851?adults...        1          NaN
# 4    https://www.airbnb.co.uk/rooms/935398?adults=1...        2          NaN
# ..                                                 ...      ...          ...
# 884  https://www.airbnb.co.uk/rooms/12680472?adults...        2          NaN
# 885  https://www.airbnb.co.uk/rooms/48565992?adults...        1          NaN
# 886  https://www.airbnb.co.uk/rooms/49742544?adults...        2          NaN
# 887  https://www.airbnb.co.uk/rooms/47777462?adults...        2          NaN
# 888  https://www.airbnb.co.uk/rooms/32377446?adults...        2          NaN
#
# [889 rows x 21 columns]

# %%
df[['guests', 'beds', 'bathrooms', 'bedrooms']] = df[['guests', 'beds', 'bathrooms', 'bedrooms']].fillna(value=1)
df.isna().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Category             0
# Title                0
# Description         60
#                   ...
# Value_rating         0
# amenities_count      0
# url                  0
# bedrooms             0
# Unnamed: 19        889
# Length: 21, dtype: int64

# %%
df.info('dict')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            889 non-null    int64
#  1   ID                    889 non-null    object
#  2   Category              889 non-null    object
#  3   Title                 889 non-null    object
#  4   Description           829 non-null    object
#  5   Amenities             889 non-null    object
#  6   Location              889 non-null    object
#  7   guests                889 non-null    int64
#  8   beds                  889 non-null    float64
#  9   bathrooms             889 non-null    float64
#  10  Price_Night           889 non-null    int64
#  11  Cleanliness_rating    889 non-null    float64
#  12  Accuracy_rating       889 non-null    float64
#  13  Communication_rating  889 non-null    float64
#  14  Location_rating       889 non-null    float64
#  15  Check-in_rating       889 non-null    float64
#  16  Value_rating          889 non-null    float64
#  17  amenities_count       889 non-null    float64
#  18  url                   889 non-null    object
#  19  bedrooms              889 non-null    int64
#  20  Unnamed: 19           0 non-null      float64
# dtypes: float64(10), int64(4), object(7)
# memory usage: 146.0+ KB

# %%
df.select_dtypes(include='number')
# Out:
#      Unnamed: 0  guests  beds  bathrooms  Price_Night  Cleanliness_rating  \
# 0             0       2   1.0        1.0          105                 4.6
# 1             1       3   3.0        0.0           92                 4.3
# 2             2       4   2.0        1.5           52                 4.2
# 3             3       2   1.0        1.0          132                 4.8
# 4             5       4   3.0        1.0          143                 5.0
# ..          ...     ...   ...        ...          ...                 ...
# 884         982       4   2.0        1.5          240                 4.9
# 885         983       2   1.0        1.0           78                 4.8
# 886         984       4   2.0        1.5          113                 4.8
# 887         985       6   3.0        2.0           80                 4.7
# 888         987       4   2.0        1.0          104                 4.9
#
#      Accuracy_rating  Communication_rating  Location_rating  Check-in_rating  \
# 0                4.7                   4.3              5.0              4.3
# 1                4.7                   4.6              4.9              4.7
# 2                4.6                   4.8              4.8              4.8
# 3                4.9                   4.9              4.9              5.0
# 4                4.9                   5.0              4.7              5.0
# ..               ...                   ...              ...              ...
# 884              5.0                   5.0              5.0              4.9
# 885              5.0                   4.9              4.9              5.0
# 886              5.0                   5.0              5.0              5.0
# 887              4.8                   5.0              5.0              5.0
# 888              4.9                   4.9              4.9              4.9
#
#      Value_rating  amenities_count  bedrooms  Unnamed: 19
# 0             4.3             13.0         1          NaN
# 1             4.5              8.0         1          NaN
# 2             4.7             51.0         1          NaN
# 3             4.6             23.0         1          NaN
# 4             4.7             32.0         2          NaN
# ..            ...              ...       ...          ...
# 884           4.8             33.0         2          NaN
# 885           4.9             54.0         1          NaN
# 886           4.8             38.0         2          NaN
# 887           4.7             24.0         2          NaN
# 888           4.3             29.0         2          NaN
#
# [889 rows x 14 columns]

# %%
rating_columns = ['Cleanliness_rating', 'Accuracy_rating', 'Communication_rating', 'Location_rating', 'Check-in_rating', 'Value_rating']
df[rating_columns].isna()
# Out:
#      Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 0                 False            False                 False
# 1                 False            False                 False
# 2                 False            False                 False
# 3                 False            False                 False
# 4                 False            False                 False
# ..                  ...              ...                   ...
# 884               False            False                 False
# 885               False            False                 False
# 886               False            False                 False
# 887               False            False                 False
# 888               False            False                 False
#
#      Location_rating  Check-in_rating  Value_rating
# 0              False            False         False
# 1              False            False         False
# 2              False            False         False
# 3              False            False         False
# 4              False            False         False
# ..               ...              ...           ...
# 884            False            False         False
# 885            False            False         False
# 886            False            False         False
# 887            False            False         False
# 888            False            False         False
#
# [889 rows x 6 columns]

# %%
import pandas as pd
df = pd.read_csv("./airbnb-property-listings/tabular_data/clean_tabular_data.csv")

def combine_description_strings(df):
        df['Description'] = df['Description'].str.replace("'About this space', ", '')
        df['Description'] = df['Description'].str.replace(" 'The space', 'The space\n", '')
        df['Description'] = df['Description'].str.replace(r'\n\n', ' ')
        df['Description'] = df['Description'].str.replace(r'\n', ' ')
        df['Description'] = df['Description'].replace("''", "")
        return df

# %%
df['Description'][0]
# Out:
# '["Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon\'s Egg.", \'The space\', \'The space The true joy of this place is how wonderfully simple it is (aviation technology aside). Days are filled with fireside discussions, wildlife watching and stunningly beautiful walks. With the nearest mobile signal a ten minute walk away, it’s a great place to ditch the digital and truly escape. Head over the bridge to your own private deck that happily houses a clever outdoor-kitchen and shower (complete with hot water). It’s the perfect spot to fry up breakfast whilst basking in peace and tranquility. There is also a flushing toilet situated just up the hill.And don’t worry, you’re not totally left to your own devices, on arrival you can expect bed linen, towels and a load of dry wood and kindling. If you feel the need to leave your new found homestead in the trees then the local area has lots of suitably chilled things to do. Head out on a moorland walk to take in some magical views - and perhaps even grab a pint at the local pub en route. Further afield, the stunning Elan Valley, a landscape bursting with impressive dams and reservoirs, is well worthy of an explore. And for those needing supplies - and perhaps a flat white - then the friendly market town of Builth Wells is just down the road.\', \'\', \'\', \'\', \'Other things to note You are entering a remote woodland hideaway for a digital detox: there is very patchy mobile signal and limited internet connectivity.\']'

# %%
import pandas as pd
df = pd.read_csv("./airbnb-property-listings/tabular_data/clean_tabular_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            889 non-null    int64
#  1   ID                    889 non-null    object
#  2   Category              889 non-null    object
#  3   Title                 889 non-null    object
#  4   Description           829 non-null    object
#  5   Amenities             889 non-null    object
#  6   Location              889 non-null    object
#  7   guests                889 non-null    int64
#  8   beds                  889 non-null    float64
#  9   bathrooms             889 non-null    float64
#  10  Price_Night           889 non-null    int64
#  11  Cleanliness_rating    889 non-null    float64
#  12  Accuracy_rating       889 non-null    float64
#  13  Communication_rating  889 non-null    float64
#  14  Location_rating       889 non-null    float64
#  15  Check-in_rating       889 non-null    float64
#  16  Value_rating          889 non-null    float64
#  17  amenities_count       889 non-null    float64
#  18  url                   889 non-null    object
#  19  bedrooms              889 non-null    int64
#  20  Unnamed: 19           0 non-null      float64
# dtypes: float64(10), int64(4), object(7)
# memory usage: 146.0+ KB

# %%
df['Category'] = df['Category'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            889 non-null    int64
#  1   ID                    889 non-null    object
#  2   Category              889 non-null    category
#  3   Title                 889 non-null    object
#  4   Description           829 non-null    object
#  5   Amenities             889 non-null    object
#  6   Location              889 non-null    object
#  7   guests                889 non-null    int64
#  8   beds                  889 non-null    float64
#  9   bathrooms             889 non-null    float64
#  10  Price_Night           889 non-null    int64
#  11  Cleanliness_rating    889 non-null    float64
#  12  Accuracy_rating       889 non-null    float64
#  13  Communication_rating  889 non-null    float64
#  14  Location_rating       889 non-null    float64
#  15  Check-in_rating       889 non-null    float64
#  16  Value_rating          889 non-null    float64
#  17  amenities_count       889 non-null    float64
#  18  url                   889 non-null    object
#  19  bedrooms              889 non-null    int64
#  20  Unnamed: 19           0 non-null      float64
# dtypes: category(1), float64(10), int64(4), object(6)
# memory usage: 140.1+ KB

# %%
df = pd.get_dummies(df, columns=['Category'], dtype=int, prefix=['Category'])

# %%
df
# Out:
#      Unnamed: 0                                    ID  \
# 0             0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf
# 1             1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd
# 2             2  d577bc30-2222-4bef-a35e-a9825642aec4
# 3             3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc
# 4             5  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5
# ..          ...                                   ...
# 884         982  cfbc88da-e88c-415a-b397-108d0948c4ba
# 885         983  4fea5054-f999-4c07-addc-67e4d893deab
# 886         984  282118e2-049e-4d9f-b2f2-b47477881b07
# 887         985  9ebf9cec-624e-480e-8704-dffa7cb1fe51
# 888         987  d2b06c80-c643-485d-a24b-15d0811a3166
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# 4                          Treehouse near Paris Disney
# ..                                                 ...
# 884                            Lancing Beach Apartment
# 885                                          Apartment
# 886               Sea front flat with a stunning view!
# 887  MP713 - Camber Sands Holiday Park - Sleeps 6 +...
# 888                      Sea Scene's ,  Hayling Island
#
#                                            Description  \
# 0    ["Escape to one of these two fabulous Tree Ten...
# 1    ["Come and spend a romantic stay with a couple...
# 2    ['Rustic cabin between the pines, 3 meters hig...
# 3    ['The Tree top cabin is situated in our peacef...
# 4    ['Charming cabin nestled in the leaves, real u...
# ..                                                 ...
# 884  ['An apartment directly on the beach at Lancin...
# 885  ['Light roomy space with outside garden 5 minu...
# 886  ['This specious two bedroom flat on the sea fr...
# 887  ['With all the modern amenities, our contempor...
# 888  ['Sea Scenes is a homely two bedroom groundflo...
#
#                                              Amenities  \
# 0    ['What this place offers', 'Bathroom', 'Shampo...
# 1    ['What this place offers', 'Bedroom and laundr...
# 2    ['What this place offers', 'Scenic views', 'Ga...
# 3    ['What this place offers', 'Bathroom', 'Hot wa...
# 4    ['What this place offers', 'Bathroom', 'Hair d...
# ..                                                 ...
# 884  ['What this place offers', 'Bathroom', 'Hair d...
# 885  ['What this place offers', 'Bathroom', 'Hair d...
# 886  ['What this place offers', 'Scenic views', 'Be...
# 887  ['What this place offers', 'Bathroom', 'Hot wa...
# 888  ['What this place offers', 'Bathroom', 'Hair d...
#
#                                         Location  guests  beds  bathrooms  \
# 0               Llandrindod Wells United Kingdom       2   1.0        1.0
# 1                    Guyonvelle Grand Est France       3   3.0        0.0
# 2                       Duclair Normandie France       4   2.0        1.5
# 3                  Barmouth Wales United Kingdom       2   1.0        1.0
# 4    Le Plessis-Feu-Aussoux Île-de-France France       4   3.0        1.0
# ..                                           ...     ...   ...        ...
# 884                       Lancing United Kingdom       4   2.0        1.5
# 885     Brighton and Hove England United Kingdom       2   1.0        1.0
# 886           East Sussex England United Kingdom       4   2.0        1.5
# 887                Camber England United Kingdom       6   3.0        2.0
# 888      Hayling Island Hampshire United Kingdom       4   2.0        1.0
#
#      Price_Night  ...  Value_rating  amenities_count  \
# 0            105  ...           4.3             13.0
# 1             92  ...           4.5              8.0
# 2             52  ...           4.7             51.0
# 3            132  ...           4.6             23.0
# 4            143  ...           4.7             32.0
# ..           ...  ...           ...              ...
# 884          240  ...           4.8             33.0
# 885           78  ...           4.9             54.0
# 886          113  ...           4.8             38.0
# 887           80  ...           4.7             24.0
# 888          104  ...           4.3             29.0
#
#                                                    url  bedrooms  Unnamed: 19  \
# 0    https://www.airbnb.co.uk/rooms/26620994?adults...         1          NaN
# 1    https://www.airbnb.co.uk/rooms/27055498?adults...         1          NaN
# 2    https://www.airbnb.co.uk/rooms/51427108?adults...         1          NaN
# 3    https://www.airbnb.co.uk/rooms/49543851?adults...         1          NaN
# 4    https://www.airbnb.co.uk/rooms/935398?adults=1...         2          NaN
# ..                                                 ...       ...          ...
# 884  https://www.airbnb.co.uk/rooms/12680472?adults...         2          NaN
# 885  https://www.airbnb.co.uk/rooms/48565992?adults...         1          NaN
# 886  https://www.airbnb.co.uk/rooms/49742544?adults...         2          NaN
# 887  https://www.airbnb.co.uk/rooms/47777462?adults...         2          NaN
# 888  https://www.airbnb.co.uk/rooms/32377446?adults...         2          NaN
#
#      Category_Amazing pools  Category_Beachfront Category_Chalets  \
# 0                         0                    0                0
# 1                         0                    0                0
# 2                         0                    0                0
# 3                         0                    0                0
# 4                         0                    0                0
# ..                      ...                  ...              ...
# 884                       0                    1                0
# 885                       0                    1                0
# 886                       0                    1                0
# 887                       0                    1                0
# 888                       0                    1                0
#
#      Category_Offbeat  Category_Treehouses
# 0                   0                    1
# 1                   0                    1
# 2                   0                    1
# 3                   0                    1
# 4                   0                    1
# ..                ...                  ...
# 884                 0                    0
# 885                 0                    0
# 886                 0                    0
# 887                 0                    0
# 888                 0                    0
#
# [889 rows x 25 columns]

# %%
df = pd.read_csv("./airbnb-property-listings/tabular_data/clean_tabular_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                    ID    Category  \
# 0           0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1           1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2           2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3           3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4           5  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                       Treehouse near Paris Disney
#
#                                          Description  \
# 0  ["Escape to one of these two fabulous Tree Ten...
# 1  ["Come and spend a romantic stay with a couple...
# 2  ['Rustic cabin between the pines, 3 meters hig...
# 3  ['The Tree top cabin is situated in our peacef...
# 4  ['Charming cabin nestled in the leaves, real u...
#
#                                            Amenities  \
# 0  ['What this place offers', 'Bathroom', 'Shampo...
# 1  ['What this place offers', 'Bedroom and laundr...
# 2  ['What this place offers', 'Scenic views', 'Ga...
# 3  ['What this place offers', 'Bathroom', 'Hot wa...
# 4  ['What this place offers', 'Bathroom', 'Hair d...
#
#                                       Location  guests  beds  bathrooms  ...  \
# 0             Llandrindod Wells United Kingdom       2   1.0        1.0  ...
# 1                  Guyonvelle Grand Est France       3   3.0        0.0  ...
# 2                     Duclair Normandie France       4   2.0        1.5  ...
# 3                Barmouth Wales United Kingdom       2   1.0        1.0  ...
# 4  Le Plessis-Feu-Aussoux Île-de-France France       4   3.0        1.0  ...
#
#    Cleanliness_rating  Accuracy_rating  Communication_rating  Location_rating  \
# 0                 4.6              4.7                   4.3              5.0
# 1                 4.3              4.7                   4.6              4.9
# 2                 4.2              4.6                   4.8              4.8
# 3                 4.8              4.9                   4.9              4.9
# 4                 5.0              4.9                   5.0              4.7
#
#    Check-in_rating  Value_rating  amenities_count  \
# 0              4.3           4.3             13.0
# 1              4.7           4.5              8.0
# 2              4.8           4.7             51.0
# 3              5.0           4.6             23.0
# 4              5.0           4.7             32.0
#
#                                                  url bedrooms  Unnamed: 19
# 0  https://www.airbnb.co.uk/rooms/26620994?adults...        1          NaN
# 1  https://www.airbnb.co.uk/rooms/27055498?adults...        1          NaN
# 2  https://www.airbnb.co.uk/rooms/51427108?adults...        1          NaN
# 3  https://www.airbnb.co.uk/rooms/49543851?adults...        1          NaN
# 4  https://www.airbnb.co.uk/rooms/935398?adults=1...        2          NaN
#
# [5 rows x 21 columns]

# %%
df = pd.read_csv("./airbnb-property-listings/tabular_data/clean_tabular_data_transformed.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/saveriotufano/Library/CloudStorage/GoogleDrive-saverio.tufano@gmail.com/My Drive/001. Data Science/005. Ai Core/018. Modelling Airbnb property listing dataset /cleaning.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/Users/saveriotufano/Library/CloudStorage/GoogleDrive-saverio.tufano%40gmail.com/My%20Drive/001.%20Data%20Science/005.%20Ai%20Core/018.%20Modelling%20Airbnb%20property%20listing%20dataset%20/cleaning.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("./airbnb-property-listings/tabular_data/clean_tabular_data_transformed.csv")
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './airbnb-property-listings/tabular_data/clean_tabular_data_transformed.csv'

# %%
df.sample(10)
# Out:
#      Unnamed: 0                                    ID  \
# 232         269  84ec7ea4-4e91-4626-973f-e931dd6380d1
# 414         452  1922ade8-b33d-4eb8-ac66-72b482dfbc8a
# 251         288  83425df8-e0fb-4832-955a-24222d8a000e
# 262         299  403f50e5-8847-4984-8441-ca92c0f35032
# 732         808  802d2eda-fb04-4772-818b-d32ed24da8f3
# 577         640  bada66a8-9df7-4cca-81c8-5d1bde123e4e
# 455         494  c1614d6c-d69a-4196-9d92-c6b38a9c0f3d
# 453         492  dcdd6136-ae0a-4856-8a5f-1e1067361efe
# 488         528  fcdaf5b3-a2aa-4fff-b9e5-25d500aee328
# 340         377  fff65af2-8386-4551-bbe8-4bdead026533
#
#                                                Title  \
# 232    Sparrowhawk Luxury Lodge with Sauna & Hot Tub
# 414  Three en-suite bedroom cottage with indoor pool
# 251                   Ivy shepherds hut with hot tub
# 262       Self Catering shepherds hut with the deer.
# 732                  Countryside workshop with sauna
# 577              Cow Shed: Daisy at Easton Farm Park
# 455                   Le Clos de Blisse - Juno Lodge
# 453       Nice T2, 4 pers 2 pools 300m beach Cabourg
# 488                          Idyllic Dorset Hideaway
# 340                              Log Cabin Snowdonia
#
#                                            Description  \
# 232  ['COVID-19 Restrictions for England Guests can...
# 414  ['This cottage is like a tardis! Very large en...
# 251  ['Set in a clearing in the woods, our holiday ...
# 262  ['Self catering shepherds hut with deer in the...
# 732  ["Beehive Encounter Holiday Workshop Of Bees A...
# 577  ['A unique place to stay! The Cow Shed is a mi...
# 455                                                NaN
# 453  ['Accommodation F2 30m2 facing south located i...
# 488  ["Our traditional English Shepherd's Hut sits ...
# 340  ['*LAST MIN CANCELLATION FOR XMAS TO COVID* Ni...
#
#                                              Amenities  \
# 232  ['What this place offers', 'Bathroom', 'Bath',...
# 414  ['What this place offers', 'Bathroom', 'Hair d...
# 251  ['What this place offers', 'Bathroom', 'Hot wa...
# 262  ['What this place offers', 'Bathroom', 'Shampo...
# 732  ['What this place offers', 'Bathroom', 'Hair d...
# 577  ['What this place offers', 'Scenic views', 'Pa...
# 455  ['What this place offers', 'Bathroom', 'Bath',...
# 453  ['What this place offers', 'Scenic views', 'Ma...
# 488  ['What this place offers', 'Bathroom', 'Shampo...
# 340  ['What this place offers', 'Bathroom', 'Hair d...
#
#                                  Location  guests  beds  bathrooms  \
# 232    Chinnor Oxfordshire United Kingdom       2   1.0        1.0
# 414               Cotleigh United Kingdom       8   4.0        3.5
# 251              Hampshire United Kingdom       2   1.0        1.0
# 262      Lodsworth England United Kingdom       2   1.0        1.0
# 732  Waldachtal Baden-Wurttemberg Germany       6   5.0        1.0
# 577             Woodbridge United Kingdom       4   2.0        0.0
# 455              Vouilly Normandie France       2   1.0        1.0
# 453              Cabourg Normandie France       4   2.0        1.0
# 488         Dorset England United Kingdom       2   1.0        1.0
# 340      Trawsfynydd Wales United Kingdom       3   2.0        1.0
#
#      Price_Night  ...  Category_Chalets  Category_Offbeat  \
# 232          235  ...                 1                 0
# 414          179  ...                 0                 0
# 251           72  ...                 1                 0
# 262           83  ...                 1                 0
# 732           71  ...                 0                 1
# 577           86  ...                 0                 1
# 455          113  ...                 0                 0
# 453           44  ...                 0                 0
# 488           85  ...                 0                 0
# 340           69  ...                 1                 0
#
#      Category_Treehouses  Area_Africa  Area_Asia  Area_Australia  \
# 232                    0            0          0               0
# 414                    0            0          0               0
# 251                    0            0          0               0
# 262                    0            0          0               0
# 732                    0            0          0               0
# 577                    0            0          0               0
# 455                    0            0          0               0
# 453                    0            0          0               0
# 488                    0            0          0               0
# 340                    0            0          0               0
#
#      Area_Central America Area_Europe  Area_North America  Area_South America
# 232                     0           1                   0                   0
# 414                     0           1                   0                   0
# 251                     0           1                   0                   0
# 262                     0           1                   0                   0
# 732                     0           1                   0                   0
# 577                     0           1                   0                   0
# 455                     0           1                   0                   0
# 453                     0           1                   0                   0
# 488                     0           1                   0                   0
# 340                     0           1                   0                   0
#
# [10 rows x 32 columns]

# %%
df_numeric = df.select_dtypes(include='number')
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              889 non-null    int64
#  1   guests                  889 non-null    int64
#  2   beds                    889 non-null    float64
#  3   bathrooms               889 non-null    float64
#  4   Price_Night             889 non-null    int64
#  5   Cleanliness_rating      889 non-null    float64
#  6   Accuracy_rating         889 non-null    float64
#  7   Communication_rating    889 non-null    float64
#  8   Location_rating         889 non-null    float64
#  9   Check-in_rating         889 non-null    float64
#  10  Value_rating            889 non-null    float64
#  11  amenities_count         889 non-null    float64
#  12  bedrooms                889 non-null    int64
#  13  Unnamed: 19             0 non-null      float64
#  14  Category_Amazing pools  889 non-null    int64
#  15  Category_Beachfront     889 non-null    int64
#  16  Category_Chalets        889 non-null    int64
#  17  Category_Offbeat        889 non-null    int64
#  18  Category_Treehouses     889 non-null    int64
#  19  Area_Africa             889 non-null    int64
#  20  Area_Asia               889 non-null    int64
#  21  Area_Australia          889 non-null    int64
#  22  Area_Central America    889 non-null    int64
#  23  Area_Europe             889 non-null    int64
#  24  Area_North America      889 non-null    int64
#  25  Area_South America      889 non-null    int64
# dtypes: float64(10), int64(16)
# memory usage: 180.7 KB

# %% [markdown]
# ## Scaling the "transformed" datafrace
# Requires to avoid pass the one-hot-encoded variables to the scaler.
# Here's a workaround that is later implemented in the regression files.

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
from tabular_data import database_utils as dbu

data_path = "./airbnb-property-listings/tabular_data/clean_tabular_data_transformed.csv"
# load the previously cleaned data
df = pd.read_csv(data_path)
#df.head()
# define labels and features
label = 'Price_Night'
features, labels = dbu.load_airbnb(df, label=label, numeric_only=True)
# create a list of numerical features
features_to_scale = ['guests', 'beds', 'bathrooms', 'Price_Night', 'Cleanliness_rating',
                        'Accuracy_rating', 'Communication_rating', 'Location_rating',
                        'Check-in_rating', 'Value_rating', 'amenities_count', 'bedrooms'] 
# remove the label from the list, there's no need to rescale it
features_to_scale.remove(label)
features_subset = features[features_to_scale]
print(features_subset)
scaler = StandardScaler() # features scaling  
scaled_features = scaler.fit_transform(features_subset) # fit and transform the data
    # now substitute the scaled features back in the original dataframe
features[features_to_scale] = scaled_features
#features.describe()
# Out:
#      guests  beds  bathrooms  Cleanliness_rating  Accuracy_rating  \
# 0         2   1.0        1.0                 4.6              4.7
# 1         3   3.0        0.0                 4.3              4.7
# 2         4   2.0        1.5                 4.2              4.6
# 3         2   1.0        1.0                 4.8              4.9
# 4         4   3.0        1.0                 5.0              4.9
# ..      ...   ...        ...                 ...              ...
# 884       4   2.0        1.5                 4.9              5.0
# 885       2   1.0        1.0                 4.8              5.0
# 886       4   2.0        1.5                 4.8              5.0
# 887       6   3.0        2.0                 4.7              4.8
# 888       4   2.0        1.0                 4.9              4.9
#
#      Communication_rating  Location_rating  Check-in_rating  Value_rating  \
# 0                     4.3              5.0              4.3           4.3
# 1                     4.6              4.9              4.7           4.5
# 2                     4.8              4.8              4.8           4.7
# 3                     4.9              4.9              5.0           4.6
# 4                     5.0              4.7              5.0           4.7
# ..                    ...              ...              ...           ...
# 884                   5.0              5.0              4.9           4.8
# 885                   4.9              4.9              5.0           4.9
# 886                   5.0              5.0              5.0           4.8
# 887                   5.0              5.0              5.0           4.7
# 888                   4.9              4.9              4.9           4.3
#
#      amenities_count  bedrooms
# 0               13.0         1
# 1                8.0         1
# 2               51.0         1
# 3               23.0         1
# 4               32.0         2
# ..               ...       ...
# 884             33.0         2
# 885             54.0         1
# 886             38.0         2
# 887             24.0         2
# 888             29.0         2
#
# [889 rows x 11 columns]

# %%
#df['Category_Treehouses'].value_counts()
# Out:
# Category_Treehouses
# 0    682
# 1    207
# Name: count, dtype: int64

# %%
df2 = pd.read_csv('test.csv')

# %%
df2
# Out:
#      Unnamed: 0    y_pred    y_test
# 0           767  4.906016  4.584967
# 1           830  4.675817  4.330733
# 2           479  4.620739  4.787492
# 3           505  4.669929  4.736198
# 4           172  3.893567  3.784190
# ..          ...       ...       ...
# 262         519  5.572439  5.472271
# 263         425  4.762778  4.948760
# 264         708  4.891550  4.787492
# 265          87  4.829193  5.407172
# 266         460  4.663120  4.727388
#
# [267 rows x 3 columns]

# %%
import numpy as np
df2[['y_pred_lin', 'y_test_lin']] = np.exp(df2[['y_pred', 'y_test']])

# %%
pd.set_option('display.max_rows', 100)
df2.sample(100)
# Out:
#      Unnamed: 0    y_pred    y_test  y_pred_lin  y_test_lin
# 6           695  5.159646  4.418841  174.102762        83.0
# 35          698  5.480153  6.068426  239.883526       432.0
# 130          58  3.825627  4.941642   45.861544       140.0
# 84           66  4.672007  4.510860  106.912135        91.0
# 44          468  4.628210  4.276666  102.330764        72.0
# 48          508  4.837102  4.634729  126.103358       103.0
# 62          161  4.331344  3.784190   76.046389        44.0
# 248         785  5.196666  5.857933  180.668954       350.0
# 68          449  4.594726  5.225747   98.961032       186.0
# 32          760  4.808510  5.236442  122.548837       188.0
# 28          887  4.901655  4.382027  134.512204        80.0
# 123         230  4.653550  4.543295  104.956914        94.0
# 229         863  5.022117  4.962845  151.732150       143.0
# 39           40  5.007959  5.356586  149.599101       212.0
# 26          727  4.437812  4.584967   84.589669        98.0
# 189         482  4.890359  4.454347  133.001312        86.0
# 134         445  5.640797  6.342121  281.687227       568.0
# 159         352  4.958489  5.176150  142.378472       177.0
# 57          485  4.714115  4.828314  111.510134       125.0
# 107         557  4.371705  4.276666   79.178493        72.0
# 77          177  4.790551  4.804021  120.367702       122.0
# 113         510  4.919699  4.890349  136.961440       133.0
# 108         350  4.472120  3.912023   87.542157        50.0
# 63          275  4.705885  4.653960  110.596119       105.0
# 115         660  4.651705  4.521789  104.763429        92.0
# 20          533  4.611590  4.787492  100.644089       120.0
# 192         604  4.767441  5.231109  117.617897       187.0
# 31          687  4.990952  4.543295  147.076336        94.0
# 52          797  5.708422  5.986452  301.395070       398.0
# 243         152  3.854033  4.110874   47.182964        61.0
# 165         244  4.704573  5.135798  110.451065       170.0
# 98          838  5.397378  6.192362  220.826713       489.0
# 200         473  4.494145  4.836282   89.491605       126.0
# 182         422  5.839420  6.507278  343.579985       670.0
# 221         419  4.857967  6.052089  128.762111       425.0
# 122          77  4.398191  3.988984   81.303637        54.0
# 141         457  4.971145  4.499810  144.191835        90.0
# 78           16  4.835342  4.934474  125.881671       139.0
# 148         668  4.738231  3.970292  114.231994        53.0
# 238         365  4.524219  5.093750   92.223896       163.0
# 47          516  5.012579  4.787492  150.291866       120.0
# 45          657  4.572027  4.143135   96.740047        63.0
# 201         547  5.031288  4.997212  153.130049       148.0
# 203         729  4.683719  4.158883  108.171660        64.0
# 70          492  4.586807  4.488636   98.180400        89.0
# 254         498  4.343009  4.174387   76.938697        65.0
# 199         733  4.962163  5.247024  142.902594       190.0
# 41          528  4.594110  5.093750   98.900093       163.0
# 76          121  4.428035  3.761200   83.766621        43.0
# 121         410  5.150165  5.370638  172.459980       215.0
# 24           29  4.706111  5.472271  110.621081       238.0
# 160         829  4.382979  4.189655   80.076216        66.0
# 234         700  5.518821  5.726848  249.340949       307.0
# 185         198  4.886059  4.727388  132.430595       113.0
# 157         151  4.736587  4.828314  114.044305       125.0
# 226         549  4.733182  5.393628  113.656694       220.0
# 161         527  4.709344  4.709530  110.979315       111.0
# 9           329  4.597387  4.553877   99.224738        95.0
# 186         842  5.078563  5.087596  160.543153       162.0
# 81          512  4.376847  4.290459   79.586672        73.0
# 183          65  4.523140  4.094345   92.124423        60.0
# 89          663  3.849058  3.496508   46.948796        33.0
# 197         845  5.998884  5.370638  402.978711       215.0
# 117         591  4.119727  5.799093   61.542443       330.0
# 265          87  4.829193  5.407172  125.110016       223.0
# 236         429  4.594469  4.948760   98.935559       141.0
# 102          37  4.973655  5.402677  144.554298       222.0
# 73          753  4.874766  4.595120  130.943484        99.0
# 8           105  4.525378  4.605170   92.330855       100.0
# 217         114  4.566222  4.262680   96.180051        71.0
# 93          394  4.604364  4.882802   99.919431       132.0
# 252         571  4.973997  4.718499  144.603670       112.0
# 263         425  4.762778  4.948760  117.070664       141.0
# 90          231  4.527957  5.616771   92.569244       275.0
# 106         229  4.466990  4.795791   87.094192       121.0
# 218         772  5.051476  5.529429  156.252982       252.0
# 194          91  4.711296  5.356586  111.196161       212.0
# 74          569  4.855591  3.713572  128.456570        41.0
# 109         844  4.777694  4.430817  118.830056        84.0
# 204         159  4.236265  4.143135   69.149118        63.0
# 5           306  4.628408  4.189655  102.350955        66.0
# 202         241  4.512061  4.499810   91.109392        90.0
# 242         590  4.000908  4.521789   54.647766        92.0
# 150         237  4.483222  4.852030   88.519383       128.0
# 261         421  4.664632  4.532599  106.126548        93.0
# 128         778  4.607540  4.304065  100.237302        74.0
# 120         325  4.717657  4.700480  111.905731       110.0
# 145          60  4.688500  4.718499  108.690001       112.0
# 251          94  4.638919  4.844187  103.432446       127.0
# 257         218  4.858509  5.713733  128.831989       303.0
# 72          593  4.524975  5.087596   92.293650       162.0
# 177         170  4.340147  3.912023   76.718836        50.0
# 241         629  4.256589  4.779123   70.568881       119.0
# 50          643  4.235461  4.406719   69.093531        82.0
# 210         432  5.017687  5.739793  151.061506       311.0
# 214         768  4.712434  4.682131  111.322774       108.0
# 96          224  4.520769  5.062595   91.906241       158.0
# 162         290  4.940225  4.682131  139.801714       108.0
# 58          693  4.848366  4.897840  127.531843       134.0
# 178          83  4.551216  4.934474   94.747516       139.0
